# %%
import numpy as np

# %% [markdown]
# **Задание 1**
#
# В магазин привезли устройства с 3-х разных предприятий.
#
# Соотношение устройств следующее:
#
# - 20% - продукция первого предприятия,
# - 30% - продукция второго предприятия,
# - 50% - продукция третьего предприятия.
#
# Далее:
# - 10% продукции высшего сорта на первом предприятии;
# - 5% продукции высшего сорта на втором предприятии;
# - 20% продукции высшего сорта на третьем предприятии.
#
# Найти вероятность того, что случайно купленная новая продукция окажется высшего сорта.

# %%
# Заводим новые переменные, равные коэффициентам объема продукции от каждого предприятия:
p_1 = 0.2 # коэффициент устройств от 1-го предприятия
p_2 = 0.3 # коэффициент устройств от 2-го предприятия
p_3 = 0.5 # коэффициент устройств от 3-го предприятия

# Заводим переменные, равные коэффициенту продукции 1-го сорта от продукции каждого предприятия

s_1 = 0.1 # коэффициент продукции 1-го сорта от продукции 1-го предприятия
s_2 = 0.05 # коэффициент продукции 1-го сорта от продукции 2-го предприятия
s_3 = 0.2 # коэффициент продукции 1-го сорта от продукции 3-го предприятия

# Находим вероятность
Probability = p_1*s_1 + p_2*s_2+p_3*s_3
Probability
# Out:
# 0.135

# %% [markdown]
# **Задание 2**
#
# Пусть брошены 3 уравновешенные монеты.
#
# Рассмотрим 3 события:
#
# - A1 - монеты 1 и 2 упали одной и той же стороной;
#
# - A2 - монеты 2 и 3 упали одной и той же стороной;
#
# - A3 - монеты 1 и 3 упали одной и той же стороной.
#
# Покажите, почему эти 3 события (A1, A2, A3) являются попарно независимыми, но не являются независимыми в совокупности.

# %% [markdown]
# **Решение**
#
# Исходя из 1 определения независимости событий (P(AB) = P(A)*P(B)) каждое из событий попарно независимо. Однако, в случае если мы знаем, что два любых события из списка  произошли, мы точно знаем, что произошло и третье (монеты из события А3 имеются и в событии А1 и в событии А2)
